# %%
from dominance_analysis import Dominance
# Out:
# /usr/lib/python3/dist-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning:
#
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#
# /usr/lib/python3/dist-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning:
#
# pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading random data set

# %%
train_data = pd.read_csv('./random_samples/train_data.csv')

# %%
car_data = pd.read_csv('./random_samples/car_data.csv')

# %% [markdown]
# ### Selecting top K features and getting R2 of the Complete Model

# %%
dominance_regression_train=Dominance(data=train_data,target='Overall Rating',objective=1)
dominance_regression_car=Dominance(data=car_data,target='Overall Rating',objective=1)
# Out:
# Selecting 10 Best Predictors for the Model
# Selected Predictors :  ['Is safe from accidents', 'Has comftarble seating', 'Gives me the ability to work read and sleep', 'Is relaxing', 'Is mostly on time', 'Can interact with tohers', 'Is clean', 'Is good for the environment', 'Is a good value for the money', 'Is convienent to use']
#
# ********************  R-Squared of Complete Model :  ********************
# R Squared : 0.0008128632434502014
#
# Selecting 10 Best Predictors for the Model
# Selected Predictors :  ['Is safe from accidents', 'Has comftarble seating', 'Gives me the ability to work read and sleep', 'Is relaxing', 'Is mostly on time', 'Can interact with tohers', 'Is clean', 'Is good for the environment', 'Is a good value for the money', 'Is convienent to use']
#
# ********************  R-Squared of Complete Model :  ********************
# R Squared : 0.0018755912275382203

# %% [markdown]
# ### Incremental Pseudo R-Squared

# %%
incr_variable_rsquare_train=dominance_regression_train.incremental_rsquare()
incr_variable_rsquare_car=dominance_regression_car.incremental_rsquare()
# Out:
# Selecting 10 Best Predictors for the Model
# Selected Predictors :  ['Is safe from accidents', 'Has comftarble seating', 'Gives me the ability to work read and sleep', 'Is relaxing', 'Is mostly on time', 'Can interact with tohers', 'Is clean', 'Is good for the environment', 'Is a good value for the money', 'Is convienent to use']
#
# Creating models for 1023 possible combinations of 10 features :
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:13<00:00,  1.33s/it]
# #########################  Model Training Done!!!!!  #########################
#
# #########################  Calculating Variable Dominances  #########################
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 23.89it/s]
# #########################  Variable Dominance Calculation Done!!!!!  #########################
#
# Selecting 10 Best Predictors for the Model
# Selected Predictors :  ['Is safe from accidents', 'Has comftarble seating', 'Gives me the ability to work read and sleep', 'Is relaxing', 'Is mostly on time', 'Can interact with tohers', 'Is clean', 'Is good for the environment', 'Is a good value for the money', 'Is convienent to use']
#
# Creating models for 1023 possible combinations of 10 features :
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:12<00:00,  1.21s/it]
# #########################  Model Training Done!!!!!  #########################
#
# #########################  Calculating Variable Dominances  #########################
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 21.40it/s]
# #########################  Variable Dominance Calculation Done!!!!!  #########################

# %% [markdown]
# ### Plot Incremental Pseudo R-Squared for Trains and Cars

# %% [raw]
# dominance_regression_train.plot_incremental_rsquare()

# %%
dominance_regression_car.plot_incremental_rsquare()

# %% [markdown]
# ### Dominance Statistics (R-Squared)

# %%
dominance_regression_train.dominance_stats().to_csv('./dominance_statistics/ds_train.csv', index=True)

# %%
dominance_regression_car.dominance_stats().to_csv('./dominance_statistics/ds_car.csv', index=True)

# %%
dominance_regression_car.dominance_stats()
# Out:
#                                             Interactional Dominance  \
# Is clean                                                   0.000545
# Is good for the environment                                0.000499
# Is mostly on time                                          0.000372
# Is a good value for the money                              0.000223
# Gives me the ability to work read and sleep                0.000106
# Is convienent to use                                       0.000067
# Is relaxing                                                0.000051
# Is safe from accidents                                     0.000018
# Has comftarble seating                                     0.000001
# Can interact with tohers                                        0.0
#
#                                             Individual Dominance  \
# Is clean                                                0.000552
# Is good for the environment                             0.000485
# Is mostly on time                                       0.000352
# Is a good value for the money                           0.000226
# Gives me the ability to work read and sleep             0.000116
# Is convienent to use                                    0.000072
# Is relaxing                                              0.00005
# Is safe from accidents                                  0.000017
# Has comftarble seating                                       0.0
# Can interact with tohers                                     0.0
#
#                                              Average Partial Dominance  \
# Is clean                                                  5.486733e-04
# Is good for the environment                               4.919468e-04
# Is mostly on time                                         3.616972e-04
# Is a good value for the money                             2.244887e-04
# Gives me the ability to work read and sleep               1.110620e-04
# Is convienent to use                                      6.950615e-05
# Is relaxing                                               5.013892e-05
# Is safe from accidents                                    1.764267e-05
# Has comftarble seating                                    4.282838e-07
# Can interact with tohers                                  6.209551e-08
#
#                                             Total Dominance  \
# Is clean                                           0.000549
# Is good for the environment                        0.000492
# Is mostly on time                                  0.000362
# Is a good value for the money                      0.000224
# Gives me the ability to work read and sleep        0.000111
# Is convienent to use                               0.000069
# Is relaxing                                         0.00005
# Is safe from accidents                             0.000018
# Has comftarble seating                                  0.0
# Can interact with tohers                                0.0
#
#                                             Percentage Relative Importance
# Is clean                                                         29.252825
# Is good for the environment                                      26.228119
# Is mostly on time                                                19.284067
# Is a good value for the money                                    11.968774
# Gives me the ability to work read and sleep                       5.921573
# Is convienent to use                                              3.705197
# Is relaxing                                                       2.673372
# Is safe from accidents                                            0.939971
# Has comftarble seating                                            0.022818
# Can interact with tohers                                          0.003285

# %%
frames = [dominance_regression_train.dominance_stats(), dominance_regression_car.dominance_stats()]
frames[0]['mode'] = 'train'
frames[1]['mode'] = 'car'
combined_data = pd.concat(frames)
combined_data
# Out:
#                                             Interactional Dominance  \
# Is good for the environment                                0.000233
# Has comftarble seating                                     0.000145
# Is mostly on time                                          0.000138
# Can interact with tohers                                   0.000103
# Is relaxing                                                0.000096
# Gives me the ability to work read and sleep                0.000055
# Is safe from accidents                                     0.000022
# Is a good value for the money                              0.000012
# Is clean                                                    0.00001
# Is convienent to use                                       0.000006
# Is clean                                                   0.000545
# Is good for the environment                                0.000499
# Is mostly on time                                          0.000372
# Is a good value for the money                              0.000223
# Gives me the ability to work read and sleep                0.000106
# Is convienent to use                                       0.000067
# Is relaxing                                                0.000051
# Is safe from accidents                                     0.000018
# Has comftarble seating                                     0.000001
# Can interact with tohers                                        0.0
#
#                                             Individual Dominance  \
# Is good for the environment                             0.000229
# Has comftarble seating                                   0.00014
# Is mostly on time                                       0.000135
# Can interact with tohers                                0.000105
# Is relaxing                                             0.000093
# Gives me the ability to work read and sleep             0.000053
# Is safe from accidents                                  0.000022
# Is a good value for the money                           0.000012
# Is clean                                                0.000011
# Is convienent to use                                    0.000006
# Is clean                                                0.000552
# Is good for the environment                             0.000485
# Is mostly on time                                       0.000352
# Is a good value for the money                           0.000226
# Gives me the ability to work read and sleep             0.000116
# Is convienent to use                                    0.000072
# Is relaxing                                              0.00005
# Is safe from accidents                                  0.000017
# Has comftarble seating                                       0.0
# Can interact with tohers                                     0.0
#
#                                              Average Partial Dominance  \
# Is good for the environment                               2.308938e-04
# Has comftarble seating                                    1.426306e-04
# Is mostly on time                                         1.364911e-04
# Can interact with tohers                                  1.037605e-04
# Is relaxing                                               9.440272e-05
# Gives me the ability to work read and sleep               5.399345e-05
# Is safe from accidents                                    2.204461e-05
# Is a good value for the money                             1.181749e-05
# Is clean                                                  1.072065e-05
# Is convienent to use                                      6.166903e-06
# Is clean                                                  5.486733e-04
# Is good for the environment                               4.919468e-04
# Is mostly on time                                         3.616972e-04
# Is a good value for the money                             2.244887e-04
# Gives me the ability to work read and sleep               1.110620e-04
# Is convienent to use                                      6.950615e-05
# Is relaxing                                               5.013892e-05
# Is safe from accidents                                    1.764267e-05
# Has comftarble seating                                    4.282838e-07
# Can interact with tohers                                  6.209551e-08
#
#                                             Total Dominance  \
# Is good for the environment                        0.000231
# Has comftarble seating                             0.000143
# Is mostly on time                                  0.000136
# Can interact with tohers                           0.000104
# Is relaxing                                        0.000094
# Gives me the ability to work read and sleep        0.000054
# Is safe from accidents                             0.000022
# Is a good value for the money                      0.000012
# Is clean                                           0.000011
# Is convienent to use                               0.000006
# Is clean                                           0.000549
# Is good for the environment                        0.000492
# Is mostly on time                                  0.000362
# Is a good value for the money                      0.000224
# Gives me the ability to work read and sleep        0.000111
# Is convienent to use                               0.000069
# Is relaxing                                         0.00005
# Is safe from accidents                             0.000018
# Has comftarble seating                                  0.0
# Can interact with tohers                                0.0
#
#                                             Percentage Relative Importance  \
# Is good for the environment                                      28.404217
# Has comftarble seating                                           17.546378
# Is mostly on time                                                16.789781
# Can interact with tohers                                         12.763184
# Is relaxing                                                      11.613237
# Gives me the ability to work read and sleep                       6.641978
# Is safe from accidents                                            2.711379
# Is a good value for the money                                     1.453318
# Is clean                                                          1.318335
# Is convienent to use                                              0.758194
# Is clean                                                         29.252825
# Is good for the environment                                      26.228119
# Is mostly on time                                                19.284067
# Is a good value for the money                                    11.968774
# Gives me the ability to work read and sleep                       5.921573
# Is convienent to use                                              3.705197
# Is relaxing                                                       2.673372
# Is safe from accidents                                            0.939971
# Has comftarble seating                                            0.022818
# Can interact with tohers                                          0.003285
#
#                                               mode
# Is good for the environment                  train
# Has comftarble seating                       train
# Is mostly on time                            train
# Can interact with tohers                     train
# Is relaxing                                  train
# Gives me the ability to work read and sleep  train
# Is safe from accidents                       train
# Is a good value for the money                train
# Is clean                                     train
# Is convienent to use                         train
# Is clean                                       car
# Is good for the environment                    car
# Is mostly on time                              car
# Is a good value for the money                  car
# Gives me the ability to work read and sleep    car
# Is convienent to use                           car
# Is relaxing                                    car
# Is safe from accidents                         car
# Has comftarble seating                         car
# Can interact with tohers                       car
